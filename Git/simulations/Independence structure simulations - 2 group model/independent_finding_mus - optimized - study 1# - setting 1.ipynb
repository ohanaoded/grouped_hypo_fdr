# %%
import independent_functions as i_f
import numpy as np
import scipy
import time

# %%
# IDEAL SCALARS ONLY FOR SPECIFICALLY 5000 ITERATIONS.

musMargFDR_scalar = [1425.5]   # between 1432.3160887391211 to 1419.
musMargPFDR_scalar = [1430.56]
musMargMFDR_scalar = [8.013]

# %%
alpha = 0.1

### TO ADD: , maxiter=17, disp=False

# %% [markdown]
# # 1.) Study 1 # - setting 1 - prob_to_1 x = [0.03, 0.15, 0.27]

# %%
# Cai & sun 09' setting - Study 1# --- 1
# All of the relevant constants, BUT the one that varies

num_hypo = [300, 150] # before optimization: [3000, 1500]

mu0 = [0, 0]
mu1 = [-2, 4]

variance_0 = [1, 1]
variance_1 = [1, 1]

# %% [markdown]
# # 1.1.) FDR

# %%
def func_marg_FDR(mu_FDR_variable, iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR, musMargMFDR):
    start = time.time()
    lev_mat_agg = pow_mat_agg = minprob_mat_agg = ev_mat_agg = er_mat_agg = 0
    for i in range(iter_num):
        if i == 1000:
            print("this is iteration no. 1000")
        if i == 2000:
            print("this is iteration no. 2000")
        if i == 3000:
            print("this is iteration no. 3000")
        if i == 4000:
            print("this is iteration no. 4000")
            
            
        lev_mat, pow_mat, minprob_mat, ev_mat, er_mat = i_f.fdep_marginals_groups(alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, 
                                                                                [mu_FDR_variable], 
                                                                                musMargPFDR, musMargMFDR)
        lev_mat_agg += lev_mat[0]
        pow_mat_agg += pow_mat[0]
        minprob_mat_agg += minprob_mat[0]
        ev_mat_agg += ev_mat[0]
        er_mat_agg += er_mat[0]
        
    # R & S RETURN
    pow_mat_r = pow_mat_agg / iter_num
    lev_mat_r = lev_mat_agg / iter_num
    ev_mat_r = ev_mat_agg / iter_num
    er_mat_r = er_mat_agg / iter_num
    minprob_mat_r = minprob_mat_agg / iter_num

    print("This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@: ")
    print(mu_FDR_variable)
    stop = time.time()
    duration = stop-start
    print(f"Time this {iter_num} iteration run took: " + str(duration))
    print("This is the calculation right now, aiming for 0: ")
    print(lev_mat_r[3] - alpha)
    
    
    return(lev_mat_r[3] - alpha)

# %%
# %%time
iter_num = 5000 

prob_to_1 = [0.03, 0.1]

root_FDR = scipy.optimize.brentq(f=func_marg_FDR, a=20, b=30, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar), maxiter=17, disp=False) 
root_FDR
# Out:
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.0
# Time this 5000 iteration run took: 51.594598054885864
# This is the calculation right now, aiming for 0:
# 0.005716490058507953
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 30.0
# Time this 5000 iteration run took: 55.333162784576416
# This is the calculation right now, aiming for 0:
# -0.03927208001059653
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 21.270653868244125
# Time this 5000 iteration run took: 51.430004835128784
# This is the calculation right now, aiming for 0:
# -0.003641071780354957
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77623640972966
# Time this 5000 iteration run took: 53.764075756073
# This is the calculation right now, aiming for 0:
# 0.0008796936163684016
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.872444870887918
# Time this 5000 iteration run took: 51.991318702697754
# This is the calculation right now, aiming for 0:
# -0.0002742177970112558
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.849581701352754
# Time this 5000 iteration run took: 48.64774537086487
# This is the calculation right now, aiming for 0:
# -0.0005292749203052172
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.812909055541205
# Time this 5000 iteration run took: 49.01211667060852
# This is the calculation right now, aiming for 0:
# -0.001292044734891598
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.791091188343778
# Time this 5000 iteration run took: 50.52715611457825
# This is the calculation right now, aiming for 0:
# -0.00040064971661539495
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.78644277671167
# Time this 5000 iteration run took: 50.107160329818726
# This is the calculation right now, aiming for 0:
# -0.0022889363768109627
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.779069961106664
# Time this 5000 iteration run took: 48.79788136482239
# This is the calculation right now, aiming for 0:
# -0.000952709968042989
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.777596730719647
# Time this 5000 iteration run took: 50.04474997520447
# This is the calculation right now, aiming for 0:
# -4.290733902610755e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77753346636515
# Time this 5000 iteration run took: 50.81899428367615
# This is the calculation right now, aiming for 0:
# -0.00184755922987756
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776654784008333
# Time this 5000 iteration run took: 49.615296602249146
# This is the calculation right now, aiming for 0:
# -0.000758647805306184
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77646105227201
# Time this 5000 iteration run took: 50.10754632949829
# This is the calculation right now, aiming for 0:
# -6.375808331071653e-06
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776459422132334
# Time this 5000 iteration run took: 48.43275022506714
# This is the calculation right now, aiming for 0:
# -0.0003206828537424683
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776347915930998
# Time this 5000 iteration run took: 48.63699722290039
# This is the calculation right now, aiming for 0:
# -0.00046773871234256914
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77629216283033
# Time this 5000 iteration run took: 47.46421456336975
# This is the calculation right now, aiming for 0:
# -0.0007358430765234958
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776264286279996
# Time this 5000 iteration run took: 47.50204849243164
# This is the calculation right now, aiming for 0:
# -0.0006901882505639528
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77625034800483
# Time this 5000 iteration run took: 48.104307413101196
# This is the calculation right now, aiming for 0:
# -0.0004711925288800878
# Wall time: 15min 51s
# 20.77625034800483

# %%
# %%time
iter_num = 5000

prob_to_1 = [0.15, 0.1]

root_FDR = scipy.optimize.brentq(f=func_marg_FDR, a=100, b=113, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar), maxiter=17, disp=False) 
root_FDR
# Out:
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 100.0
# Time this 5000 iteration run took: 48.370118379592896
# This is the calculation right now, aiming for 0:
# 0.015977442252995355
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 113.0
# Time this 5000 iteration run took: 48.57702565193176
# This is the calculation right now, aiming for 0:
# -0.003023947385994097
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.9311346819993
# Time this 5000 iteration run took: 48.0831823348999
# This is the calculation right now, aiming for 0:
# -0.0005305969692291634
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.5050210482306
# Time this 5000 iteration run took: 47.64693212509155
# This is the calculation right now, aiming for 0:
# -0.0001453123615054175
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.34643212419603
# Time this 5000 iteration run took: 47.50501346588135
# This is the calculation right now, aiming for 0:
# -0.0006528292979617323
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 105.17321606209802
# Time this 5000 iteration run took: 48.4136757850647
# This is the calculation right now, aiming for 0:
# 0.006777075885779207
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 109.89188702213816
# Time this 5000 iteration run took: 48.277403593063354
# This is the calculation right now, aiming for 0:
# 0.00010600684340547617
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 109.95538543612746
# Time this 5000 iteration run took: 47.59770202636719
# This is the calculation right now, aiming for 0:
# 0.00026374363452673355
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.15090878016174
# Time this 5000 iteration run took: 47.70550751686096
# This is the calculation right now, aiming for 0:
# 0.00010663935022513227
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.24867045217889
# Time this 5000 iteration run took: 47.834166288375854
# This is the calculation right now, aiming for 0:
# -0.00016313885251251214
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.18955252926763
# Time this 5000 iteration run took: 47.940836668014526
# This is the calculation right now, aiming for 0:
# -0.00017341835050055376
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.16562340605576
# Time this 5000 iteration run took: 46.912453174591064
# This is the calculation right now, aiming for 0:
# -0.0005815173378318356
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.15318901396805
# Time this 5000 iteration run took: 48.0326087474823
# This is the calculation right now, aiming for 0:
# -0.0002869382484654154
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.15152660661394
# Time this 5000 iteration run took: 48.44535708427429
# This is the calculation right now, aiming for 0:
# -2.7835696557398926e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.15139871947012
# Time this 5000 iteration run took: 48.196877002716064
# This is the calculation right now, aiming for 0:
# 0.0003389962109440481
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.15151690236615
# Time this 5000 iteration run took: 47.987805128097534
# This is the calculation right now, aiming for 0:
# 0.0003466895042193441
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.15152588536876
# Time this 5000 iteration run took: 47.82561659812927
# This is the calculation right now, aiming for 0:
# 0.00020736804665885678
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.15152652125661
# Time this 5000 iteration run took: 48.06270885467529
# This is the calculation right now, aiming for 0:
# -0.0013768801338827075
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.15152596860244
# Time this 5000 iteration run took: 48.71202278137207
# This is the calculation right now, aiming for 0:
# -0.0013132628712321098
# Wall time: 15min 12s
# 110.15152596860244

# %%
# %%time
iter_num = 5000

prob_to_1 = [0.27, 0.1]

root_FDR = scipy.optimize.brentq(f=func_marg_FDR, a=200, b=250, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar), maxiter=17, disp=False) 
root_FDR
# Out:
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 200.0
# Time this 5000 iteration run took: 51.44257569313049
# This is the calculation right now, aiming for 0:
# 0.013757663702019765
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 250.0
# Time this 5000 iteration run took: 50.4456205368042
# This is the calculation right now, aiming for 0:
# -0.014309675245493522
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 224.50831503433045
# Time this 5000 iteration run took: 49.17399477958679
# This is the calculation right now, aiming for 0:
# -0.0010680848566271828
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.7426733167425
# Time this 5000 iteration run took: 47.6937472820282
# This is the calculation right now, aiming for 0:
# 0.00014276035399068965
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.95084495950348
# Time this 5000 iteration run took: 49.41509294509888
# This is the calculation right now, aiming for 0:
# -0.0004036568056169504
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.7970615380654
# Time this 5000 iteration run took: 47.787261724472046
# This is the calculation right now, aiming for 0:
# 0.00011459275564079663
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.87395324878446
# Time this 5000 iteration run took: 47.79539895057678
# This is the calculation right now, aiming for 0:
# 2.579923009977947e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.8923757892979
# Time this 5000 iteration run took: 50.979021072387695
# This is the calculation right now, aiming for 0:
# 0.0001438970642864551
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.9216103744007
# Time this 5000 iteration run took: 49.067527532577515
# This is the calculation right now, aiming for 0:
# -6.504854271828509e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91250911984372
# Time this 5000 iteration run took: 48.55579400062561
# This is the calculation right now, aiming for 0:
# 7.244498285870205e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91730454732007
# Time this 5000 iteration run took: 48.573583364486694
# This is the calculation right now, aiming for 0:
# -0.0005259223930087625
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.9130897074147
# Time this 5000 iteration run took: 47.45773673057556
# This is the calculation right now, aiming for 0:
# 3.15550662497166e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91351239058548
# Time this 5000 iteration run took: 48.61337733268738
# This is the calculation right now, aiming for 0:
# 5.39790610324109e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91540846895276
# Time this 5000 iteration run took: 49.71953225135803
# This is the calculation right now, aiming for 0:
# 7.228877888633412e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.9163565081364
# Time this 5000 iteration run took: 47.93094539642334
# This is the calculation right now, aiming for 0:
# -9.777599611690557e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91581144831707
# Time this 5000 iteration run took: 47.94644021987915
# This is the calculation right now, aiming for 0:
# -0.0002600328740725022
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91549612765903
# Time this 5000 iteration run took: 47.02756309509277
# This is the calculation right now, aiming for 0:
# 0.00012324030579582979
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91565378798805
# Time this 5000 iteration run took: 48.4117910861969
# This is the calculation right now, aiming for 0:
# 0.00011838599813207562
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91573261815256
# Time this 5000 iteration run took: 48.76268911361694
# This is the calculation right now, aiming for 0:
# 0.0001509896008092121
# Wall time: 15min 26s
# 222.91573261815256

# %% [markdown]
# # 1.2.) pFDR

# %%
def func_marg_pFDR(mu_pFDR_variable, iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargFDR, musMargMFDR):
    start = time.time()
    lev_mat_agg = pow_mat_agg = minprob_mat_agg = ev_mat_agg = er_mat_agg = 0
    for i in range(iter_num):
        
        if i == 1000:
            print("this is iteration no. 1000")
        if i == 2000:
            print("this is iteration no. 2000")
        if i == 3000:
            print("this is iteration no. 3000")
        if i == 4000:
            print("this is iteration no. 4000")
            
            
        lev_mat, pow_mat, minprob_mat, ev_mat, er_mat = i_f.fdep_marginals_groups(alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargFDR,
                                                                                [mu_pFDR_variable], 
                                                                                musMargMFDR)
        lev_mat_agg += lev_mat[0]
        pow_mat_agg += pow_mat[0]
        minprob_mat_agg += minprob_mat[0]
        ev_mat_agg += ev_mat[0]
        er_mat_agg += er_mat[0]
        
    # R & S RETURN
    pow_mat_r = pow_mat_agg / iter_num
    lev_mat_r = lev_mat_agg / iter_num
    ev_mat_r = ev_mat_agg / iter_num
    er_mat_r = er_mat_agg / iter_num
    minprob_mat_r = minprob_mat_agg / iter_num

    print("This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@: ")
    print(mu_pFDR_variable)
    stop = time.time()
    duration = stop-start
    print(f"Time this {iter_num} iteration run took: " + str(duration))
    print("This is the calculation right now, aiming for 0: ")
    print(lev_mat_r[4] - alpha*minprob_mat_r[4])
    
    
    return(lev_mat_r[4] - alpha*minprob_mat_r[4])

# %%
# %%time
iter_num = 5000 

prob_to_1 = [0.03, 0.1]

root_pFDR = scipy.optimize.brentq(f=func_marg_pFDR, a=16, b=23, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar))#, maxiter=17, disp=False) 
root_pFDR
# Out:
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 16.0
# Time this 5000 iteration run took: 51.85959458351135
# This is the calculation right now, aiming for 0:
# 0.04486882322107569
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 23.0
# Time this 5000 iteration run took: 50.60170269012451
# This is the calculation right now, aiming for 0:
# -0.013612681770625523
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 21.37061695987645
# Time this 5000 iteration run took: 51.140784740448
# This is the calculation right now, aiming for 0:
# -0.0050121807764194615
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.516463979285653
# Time this 5000 iteration run took: 50.28218722343445
# This is the calculation right now, aiming for 0:
# 0.001141914998281951
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.67495519149159
# Time this 5000 iteration run took: 48.87528443336487
# This is the calculation right now, aiming for 0:
# 0.000987726014349155
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 21.02278607568402
# Time this 5000 iteration run took: 49.54819440841675
# This is the calculation right now, aiming for 0:
# -0.0005714274223690419
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.895306572452583
# Time this 5000 iteration run took: 50.31546974182129
# This is the calculation right now, aiming for 0:
# -0.0015157798563003033
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.7618919923294
# Time this 5000 iteration run took: 55.923237562179565
# This is the calculation right now, aiming for 0:
# 0.000580595601920017
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.82859928239099
# Time this 5000 iteration run took: 50.16193342208862
# This is the calculation right now, aiming for 0:
# -0.002141813402340473
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776118348165408
# Time this 5000 iteration run took: 49.807340145111084
# This is the calculation right now, aiming for 0:
# 0.0001450383197789118
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.78055519844413
# Time this 5000 iteration run took: 50.14494466781616
# This is the calculation right now, aiming for 0:
# -0.0003562907954802047
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.777401962641306
# Time this 5000 iteration run took: 53.06080436706543
# This is the calculation right now, aiming for 0:
# -0.0012618027945731913
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776250682431822
# Time this 5000 iteration run took: 51.51706624031067
# This is the calculation right now, aiming for 0:
# -0.0010746629001539554
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776134084428794
# Time this 5000 iteration run took: 49.26879262924194
# This is the calculation right now, aiming for 0:
# 0.00018883916051580518
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776192383430306
# Time this 5000 iteration run took: 51.960875034332275
# This is the calculation right now, aiming for 0:
# 0.0004594228399911332
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776221532931064
# Time this 5000 iteration run took: 57.241124391555786
# This is the calculation right now, aiming for 0:
# -0.0014807741554212356
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77619928579458
# Time this 5000 iteration run took: 49.660916805267334
# This is the calculation right now, aiming for 0:
# -0.0014417315084677557
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194051418916
# Time this 5000 iteration run took: 52.98709750175476
# This is the calculation right now, aiming for 0:
# 0.00047744740656061047
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776196668606747
# Time this 5000 iteration run took: 52.74495720863342
# This is the calculation right now, aiming for 0:
# -0.00013503482350891993
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776196091591643
# Time this 5000 iteration run took: 49.68747901916504
# This is the calculation right now, aiming for 0:
# -0.0002895198134714866
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776195071505278
# Time this 5000 iteration run took: 51.0554575920105
# This is the calculation right now, aiming for 0:
# -0.00022225120154290012
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.7761945614621
# Time this 5000 iteration run took: 48.94716763496399
# This is the calculation right now, aiming for 0:
# -0.0001330113142505307
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77619430644051
# Time this 5000 iteration run took: 48.12837839126587
# This is the calculation right now, aiming for 0:
# -0.0008030934755415831
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194146503265
# Time this 5000 iteration run took: 49.38088321685791
# This is the calculation right now, aiming for 0:
# 0.0003244437494972635
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194226471887
# Time this 5000 iteration run took: 48.8029260635376
# This is the calculation right now, aiming for 0:
# -0.0004231490958021694
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77619418120841
# Time this 5000 iteration run took: 50.58709478378296
# This is the calculation right now, aiming for 0:
# 0.00010438039348542594
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.7761941944126
# Time this 5000 iteration run took: 48.908326625823975
# This is the calculation right now, aiming for 0:
# 0.0007421981762771174
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194214830845
# Time this 5000 iteration run took: 48.72026968002319
# This is the calculation right now, aiming for 0:
# -0.0012016509621147198
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194204621724
# Time this 5000 iteration run took: 48.2908501625061
# This is the calculation right now, aiming for 0:
# -0.001014072384762768
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194198726966
# Time this 5000 iteration run took: 48.52855658531189
# This is the calculation right now, aiming for 0:
# -0.0003206760232379313
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197425294
# Time this 5000 iteration run took: 48.581613063812256
# This is the calculation right now, aiming for 0:
# 8.489919234232202e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197697773
# Time this 5000 iteration run took: 48.643441677093506
# This is the calculation right now, aiming for 0:
# -0.00021808821798881273
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197501646
# Time this 5000 iteration run took: 48.69271683692932
# This is the calculation right now, aiming for 0:
# -0.0014287520684851812
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197429575
# Time this 5000 iteration run took: 48.5218768119812
# This is the calculation right now, aiming for 0:
# 0.00016306295453964725
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.77619419746561
# Time this 5000 iteration run took: 48.613327503204346
# This is the calculation right now, aiming for 0:
# 0.00031054122180679267
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197483626
# Time this 5000 iteration run took: 49.05999565124512
# This is the calculation right now, aiming for 0:
# -0.0006476633137039722
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197471447
# Time this 5000 iteration run took: 48.90774369239807
# This is the calculation right now, aiming for 0:
# -0.00014354531196617004
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197469604
# Time this 5000 iteration run took: 48.944512367248535
# This is the calculation right now, aiming for 0:
# -0.00037869419673643157
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197467408
# Time this 5000 iteration run took: 48.328033447265625
# This is the calculation right now, aiming for 0:
# 0.0008627131506662167
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 20.776194197468595
# Time this 5000 iteration run took: 48.359869956970215
# This is the calculation right now, aiming for 0:
# -0.0022241652169011222
# Wall time: 33min 24s
# 20.776194197467408

# %%
# %%time
iter_num = 5000

prob_to_1 = [0.15, 0.1]

root_pFDR = scipy.optimize.brentq(f=func_marg_pFDR, a=105, b=130, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar), maxiter=17, disp=False) 
root_pFDR
# Out:
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 105.0
# Time this 5000 iteration run took: 50.09502840042114
# This is the calculation right now, aiming for 0:
# 0.008518447735537144
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 130.0
# Time this 5000 iteration run took: 47.62003302574158
# This is the calculation right now, aiming for 0:
# -0.02331495875793871
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 111.68986504576802
# Time this 5000 iteration run took: 48.470704793930054
# This is the calculation right now, aiming for 0:
# -0.0031426618682549173
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 109.88695052927382
# Time this 5000 iteration run took: 48.12685227394104
# This is the calculation right now, aiming for 0:
# 0.0009167953567629228
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.29412409109281
# Time this 5000 iteration run took: 53.42019510269165
# This is the calculation right now, aiming for 0:
# -0.0004108752067650545
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.16811578300991
# Time this 5000 iteration run took: 53.30516028404236
# This is the calculation right now, aiming for 0:
# 4.2481361712101706e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17992327602227
# Time this 5000 iteration run took: 51.94165873527527
# This is the calculation right now, aiming for 0:
# -0.00016583662617707107
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17052363259916
# Time this 5000 iteration run took: 48.935626745224
# This is the calculation right now, aiming for 0:
# 0.00016817422876784505
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17525634640162
# Time this 5000 iteration run took: 49.036542892456055
# This is the calculation right now, aiming for 0:
# -0.0003688644561649773
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17288998950039
# Time this 5000 iteration run took: 49.456950664520264
# This is the calculation right now, aiming for 0:
# 0.000476976107082111
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.1742243966591
# Time this 5000 iteration run took: 48.69805097579956
# This is the calculation right now, aiming for 0:
# 0.00020204618237119887
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17458960531314
# Time this 5000 iteration run took: 49.5507435798645
# This is the calculation right now, aiming for 0:
# -0.0001829868177118943
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17441604000993
# Time this 5000 iteration run took: 48.8603949546814
# This is the calculation right now, aiming for 0:
# 0.0003993772383846933
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17453506870126
# Time this 5000 iteration run took: 48.660948038101196
# This is the calculation right now, aiming for 0:
# 0.0008464494051142329
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17457991119045
# Time this 5000 iteration run took: 47.27692770957947
# This is the calculation right now, aiming for 0:
# -0.00023527329112946194
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17455748994585
# Time this 5000 iteration run took: 48.02780556678772
# This is the calculation right now, aiming for 0:
# 0.0006679976545053978
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17457407117087
# Time this 5000 iteration run took: 49.093656063079834
# This is the calculation right now, aiming for 0:
# -0.0005251244470045185
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.17456578055837
# Time this 5000 iteration run took: 50.247658252716064
# This is the calculation right now, aiming for 0:
# -9.819536771370208e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 110.1745642453046
# Time this 5000 iteration run took: 47.49936008453369
# This is the calculation right now, aiming for 0:
# -0.0006403275148383208
# Wall time: 15min 38s
# 110.1745642453046

# %%
# %%time
iter_num = 5000

prob_to_1 = [0.27, 0.1]

root_pFDR = scipy.optimize.brentq(f=func_marg_pFDR, a=215, b=255, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar), maxiter=17, disp=False) 
root_pFDR
# Out:
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 215.0
# Time this 5000 iteration run took: 48.41791391372681
# This is the calculation right now, aiming for 0:
# 0.004648725712920979
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 255.0
# Time this 5000 iteration run took: 48.26010513305664
# This is the calculation right now, aiming for 0:
# -0.016521146783401636
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 223.78366313019316
# Time this 5000 iteration run took: 48.761202812194824
# This is the calculation right now, aiming for 0:
# -0.00048380517812127155
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.95569311004635
# Time this 5000 iteration run took: 48.1052086353302
# This is the calculation right now, aiming for 0:
# -0.00013392795177692707
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.64763322177066
# Time this 5000 iteration run took: 47.80469584465027
# This is the calculation right now, aiming for 0:
# 0.000358326039035059
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.87187900059985
# Time this 5000 iteration run took: 48.614105224609375
# This is the calculation right now, aiming for 0:
# 0.0002489942944619017
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92637892911685
# Time this 5000 iteration run took: 49.019243001937866
# This is the calculation right now, aiming for 0:
# -0.00022135375217623154
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.89912896485833
# Time this 5000 iteration run took: 48.21894288063049
# This is the calculation right now, aiming for 0:
# 0.000267483164569135
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.9140396772546
# Time this 5000 iteration run took: 48.386008977890015
# This is the calculation right now, aiming for 0:
# 5.8092223664832354e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.91660480483205
# Time this 5000 iteration run took: 48.093724489212036
# This is the calculation right now, aiming for 0:
# 0.00010079973281118537
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92149186697446
# Time this 5000 iteration run took: 48.18847370147705
# This is the calculation right now, aiming for 0:
# 0.0004625178043589223
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92479709765743
# Time this 5000 iteration run took: 48.266406536102295
# This is the calculation right now, aiming for 0:
# 1.5110394146741757e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92489817893
# Time this 5000 iteration run took: 48.097453355789185
# This is the calculation right now, aiming for 0:
# -6.793925432946324e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.9248154887993
# Time this 5000 iteration run took: 48.38697695732117
# This is the calculation right now, aiming for 0:
# 0.0003688725863736919
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92488531777263
# Time this 5000 iteration run took: 48.026526927948
# This is the calculation right now, aiming for 0:
# -0.00011122261741176864
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92485040328597
# Time this 5000 iteration run took: 48.43230938911438
# This is the calculation right now, aiming for 0:
# -1.459400896311469e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92484604387866
# Time this 5000 iteration run took: 48.65745520591736
# This is the calculation right now, aiming for 0:
# -1.5950942891168607e-05
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92483076633897
# Time this 5000 iteration run took: 48.12387251853943
# This is the calculation right now, aiming for 0:
# 0.00011966623657710951
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 222.92484424697383
# Time this 5000 iteration run took: 48.05825138092041
# This is the calculation right now, aiming for 0:
# 9.076290131859732e-06
# Wall time: 15min 17s
# 222.92484424697383

# %% [markdown]
# # 1.3.) mFDR

# %%
def func_marg_mFDR(mu_mFDR_variable, iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargFDR, musMargPFDR):
    print("started")
    start = time.time()
    lev_mat_agg = pow_mat_agg = minprob_mat_agg = ev_mat_agg = er_mat_agg = 0
    for i in range(iter_num):
        
        if i == 1000:
            print("this is iteration no. 1000")
        if i == 2000:
            print("this is iteration no. 2000")
        if i == 3000:
            print("this is iteration no. 3000")
        if i == 4000:
            print("this is iteration no. 4000")

        
        lev_mat, pow_mat, minprob_mat, ev_mat, er_mat = i_f.fdep_marginals_groups(alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargFDR, musMargPFDR,
                                                                                [mu_mFDR_variable])
        lev_mat_agg += lev_mat[0]
        pow_mat_agg += pow_mat[0]
        minprob_mat_agg += minprob_mat[0]
        ev_mat_agg += ev_mat[0]
        er_mat_agg += er_mat[0]
        
    # R & S RETURN
    pow_mat_r = pow_mat_agg / iter_num
    lev_mat_r = lev_mat_agg / iter_num
    ev_mat_r = ev_mat_agg / iter_num
    er_mat_r = er_mat_agg / iter_num
    minprob_mat_r = minprob_mat_agg / iter_num

    
    print("This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@: ")
    print(mu_mFDR_variable)
    stop = time.time()
    duration = stop-start
    print(f"Time this {iter_num} iteration run took: " + str(duration))
    print("This is the calculation right now, aiming for 0: ")
    print(ev_mat_r[5] / er_mat_r[5] - alpha)
    
    return(ev_mat_r[5] / er_mat_r[5] - alpha)

# %%
# %%time
iter_num = 5000 

prob_to_1 = [0.03, 0.1]

root_mFDR = scipy.optimize.brentq(f=func_marg_mFDR, a=0.9, b=1.5, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar), maxiter=17, disp=False) 
root_mFDR
# Out:
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 0.9
# Time this 5000 iteration run took: 49.31892538070679
# This is the calculation right now, aiming for 0:
# 0.021599156970010205
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.5
# Time this 5000 iteration run took: 49.13437032699585
# This is the calculation right now, aiming for 0:
# -0.02013181565489143
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.2105485773957962
# Time this 5000 iteration run took: 48.7685546875
# This is the calculation right now, aiming for 0:
# -0.004942746053502353
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.133897624742909
# Time this 5000 iteration run took: 49.74780869483948
# This is the calculation right now, aiming for 0:
# 0.0006402640901938816
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.142688017595447
# Time this 5000 iteration run took: 52.62531328201294
# This is the calculation right now, aiming for 0:
# 0.0003276891413634825
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1513304897043657
# Time this 5000 iteration run took: 50.05179047584534
# This is the calculation right now, aiming for 0:
# -0.0015644287668376
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1441847764667386
# Time this 5000 iteration run took: 48.8967170715332
# This is the calculation right now, aiming for 0:
# -0.000801179583943698
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1431224982559227
# Time this 5000 iteration run took: 48.98207449913025
# This is the calculation right now, aiming for 0:
# -0.0007190367660064867
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.142824036579565
# Time this 5000 iteration run took: 49.720295429229736
# This is the calculation right now, aiming for 0:
# -0.0003001875525416725
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1427590059671249
# Time this 5000 iteration run took: 50.406875133514404
# This is the calculation right now, aiming for 0:
# -0.000788934642282399
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.142708850143439
# Time this 5000 iteration run took: 49.71345663070679
# This is the calculation right now, aiming for 0:
# -0.00029536343853328595
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1426989742947435
# Time this 5000 iteration run took: 49.17928743362427
# This is the calculation right now, aiming for 0:
# -0.00015787785454171588
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1426913209483291
# Time this 5000 iteration run took: 49.40357255935669
# This is the calculation right now, aiming for 0:
# -0.0008054541299805512
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.14268897287877
# Time this 5000 iteration run took: 49.37436842918396
# This is the calculation right now, aiming for 0:
# -0.0007566535557201465
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1426883062827529
# Time this 5000 iteration run took: 49.22623825073242
# This is the calculation right now, aiming for 0:
# -9.282812029272336e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1426882425557614
# Time this 5000 iteration run took: 49.00819969177246
# This is the calculation right now, aiming for 0:
# -0.0005307350904675268
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1426881034702971
# Time this 5000 iteration run took: 48.9305784702301
# This is the calculation right now, aiming for 0:
# -1.0906525269194223e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1426881007041771
# Time this 5000 iteration run took: 49.08182191848755
# This is the calculation right now, aiming for 0:
# -0.0008685779399046217
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 1.1426880403611228
# Time this 5000 iteration run took: 48.75908923149109
# This is the calculation right now, aiming for 0:
# -0.0004930165590764785
# Wall time: 15min 40s
# 1.1426880403611228

# %%
# %%time
iter_num = 5000 

prob_to_1 = [0.15, 0.1]

root_mFDR = scipy.optimize.brentq(f=func_marg_mFDR, a=2.5, b=5, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar), maxiter=17, disp=False) 
root_mFDR
# Out:
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 2.5
# Time this 5000 iteration run took: 49.093985080718994
# This is the calculation right now, aiming for 0:
# 0.01689694124395634
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 5.0
# Time this 5000 iteration run took: 49.281113624572754
# This is the calculation right now, aiming for 0:
# -0.024340950110485093
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.5243577380525117
# Time this 5000 iteration run took: 49.196919441223145
# This is the calculation right now, aiming for 0:
# -0.006308797855625922
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.2458720637334446
# Time this 5000 iteration run took: 49.05888342857361
# This is the calculation right now, aiming for 0:
# -0.0009998988993545482
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.196351426435439
# Time this 5000 iteration run took: 49.36949968338013
# This is the calculation right now, aiming for 0:
# -0.0003862198229264979
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.166057383406276
# Time this 5000 iteration run took: 48.984084129333496
# This is the calculation right now, aiming for 0:
# 0.00045627671961651073
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.1824639392546192
# Time this 5000 iteration run took: 49.30186438560486
# This is the calculation right now, aiming for 0:
# -0.00012090195988367913
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.177461192121825
# Time this 5000 iteration run took: 52.48849892616272
# This is the calculation right now, aiming for 0:
# 3.517118749570003e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.1785885645132677
# Time this 5000 iteration run took: 49.149817943573
# This is the calculation right now, aiming for 0:
# 2.6190519516633426e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.1805262518839434
# Time this 5000 iteration run took: 49.18936324119568
# This is the calculation right now, aiming for 0:
# 4.083128944504244e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.1814950955692813
# Time this 5000 iteration run took: 50.126484632492065
# This is the calculation right now, aiming for 0:
# -1.0565935680703631e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.1812959264499585
# Time this 5000 iteration run took: 49.77389430999756
# This is the calculation right now, aiming for 0:
# 0.0001198512767742882
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.1814789596002266
# Time this 5000 iteration run took: 48.76621437072754
# This is the calculation right now, aiming for 0:
# 3.174916664377969e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.181491066473242
# Time this 5000 iteration run took: 49.09610176086426
# This is the calculation right now, aiming for 0:
# -0.0002629761329025204
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.181480263808347
# Time this 5000 iteration run took: 48.79007911682129
# This is the calculation right now, aiming for 0:
# -0.00012668600089357773
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.1814792209533187
# Time this 5000 iteration run took: 48.693567991256714
# This is the calculation right now, aiming for 0:
# -0.00029064973969836205
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.18147898533773
# Time this 5000 iteration run took: 50.18511390686035
# This is the calculation right now, aiming for 0:
# -0.00022407763965942573
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.1814789627943574
# Time this 5000 iteration run took: 50.26176929473877
# This is the calculation right now, aiming for 0:
# -0.0001492086492210637
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.181478960160639
# Time this 5000 iteration run took: 48.98548102378845
# This is the calculation right now, aiming for 0:
# -0.00011987413833673688
# Wall time: 15min 39s
# 3.181478960160639

# %%
# %%time
iter_num = 5000

prob_to_1 = [0.27, 0.1]

root_mFDR = scipy.optimize.brentq(f=func_marg_mFDR, a=2, b=4.5, args=(iter_num, alpha, num_hypo, prob_to_1, mu0, mu1, variance_0, variance_1, musMargPFDR_scalar, musMargMFDR_scalar), maxiter=17, disp=False) 
root_mFDR
# Out:
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 2.0
# Time this 5000 iteration run took: 50.131606578826904
# This is the calculation right now, aiming for 0:
# 0.039307814588263934
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 4.5
# Time this 5000 iteration run took: 48.62691879272461
# This is the calculation right now, aiming for 0:
# -0.011708333486191713
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.926243751826189
# Time this 5000 iteration run took: 48.69969987869263
# This is the calculation right now, aiming for 0:
# -0.0044885712456603916
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6060939178014264
# Time this 5000 iteration run took: 48.17211866378784
# This is the calculation right now, aiming for 0:
# -1.976139647580366e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.604740575556346
# Time this 5000 iteration run took: 48.03263807296753
# This is the calculation right now, aiming for 0:
# 7.728524219556554e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6058183396563344
# Time this 5000 iteration run took: 48.814356088638306
# This is the calculation right now, aiming for 0:
# -0.00012157681443585033
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.605159435045724
# Time this 5000 iteration run took: 48.92013907432556
# This is the calculation right now, aiming for 0:
# -0.00013393388473578738
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6048938365680394
# Time this 5000 iteration run took: 49.11637282371521
# This is the calculation right now, aiming for 0:
# -0.00015962949066471166
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.604790571663658
# Time this 5000 iteration run took: 48.85088801383972
# This is the calculation right now, aiming for 0:
# -8.054839619195397e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.604765056784188
# Time this 5000 iteration run took: 49.2945442199707
# This is the calculation right now, aiming for 0:
# 2.3761635561073136e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6047734493542642
# Time this 5000 iteration run took: 48.804508447647095
# This is the calculation right now, aiming for 0:
# -0.00010215240807909254
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6047666405725076
# Time this 5000 iteration run took: 48.99224519729614
# This is the calculation right now, aiming for 0:
# -0.00018025683256339686
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.604765241244944
# Time this 5000 iteration run took: 48.96122431755066
# This is the calculation right now, aiming for 0:
# -0.00021127672829407418
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6047650754325873
# Time this 5000 iteration run took: 48.60544562339783
# This is the calculation right now, aiming for 0:
# -1.7805835471590425e-05
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6047650674443616
# Time this 5000 iteration run took: 48.858107805252075
# This is the calculation right now, aiming for 0:
# -0.00021718053261822468
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6047650578354906
# Time this 5000 iteration run took: 48.92971992492676
# This is the calculation right now, aiming for 0:
# 0.0001872771249187971
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.604765062639926
# Time this 5000 iteration run took: 49.41620397567749
# This is the calculation right now, aiming for 0:
# 0.00021109249788056617
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6047650650421437
# Time this 5000 iteration run took: 48.857465982437134
# This is the calculation right now, aiming for 0:
# 0.00014469398539934675
# started
# this is iteration no. 1000
# this is iteration no. 2000
# this is iteration no. 3000
# this is iteration no. 4000
# This is MU now!@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@:
# 3.6047650662432527
# Time this 5000 iteration run took: 48.75874400138855
# This is the calculation right now, aiming for 0:
# 5.2626169573258275e-05
# Wall time: 15min 28s
# 3.6047650662432527
